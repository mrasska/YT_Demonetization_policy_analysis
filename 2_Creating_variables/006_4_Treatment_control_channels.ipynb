# %% [markdown]
# ## Treatment and control groups for selected channels
#
# The examined intervention targeted specific content: "videos that are perceived to be hateful or inflammatory” and “content that is harassing or attacking people based on their race, religion, gender or similar categories".
# To estimate the effect on creators’ content supply, we categorised channels based on the topic of their published videos before the implementation of the moderation. The categorisation relied on keyword matching. A total of 96 words and expressions based on this condition  was generated.
# The keyword matching was done on the title, description and tags for videos published before the March 2017’s moderation update (n videos = 2,742,395).

# %%
import pandas as pd
import numpy as np
import re

# %%
db_video=pd.read_csv('video_database_per_period_selected.csv', sep=';')
db_video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11845978 entries, 0 to 11845977
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0.1    int64
#  1   Unnamed: 0      int64
#  2   category        object
#  3   channel         object
#  4   date_crawled    object
#  5   description     object
#  6   id              object
#  7   duration        int64
#  8   tags            object
#  9   title           object
#  10  upload          object
#  11  week            object
#  12  before_updates  float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 1.1+ GB

# %% [markdown]
# ## Selecting channels

# %%
db_chan=pd.read_csv('weekly_uploads_cat_completed.csv', sep=';')
chan=db_chan['channel'].unique().tolist()
len(chan)
# Out:
# 53535

# %%
db_video=db_video[db_video['channel'].isin(chan)]
db_video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7807776 entries, 141 to 11845922
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0.1    int64
#  1   Unnamed: 0      int64
#  2   category        object
#  3   channel         object
#  4   date_crawled    object
#  5   description     object
#  6   id              object
#  7   duration        int64
#  8   tags            object
#  9   title           object
#  10  upload          object
#  11  week            object
#  12  before_updates  float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 834.0+ MB

# %%
out=pd.read_csv('outliers_995.csv', sep=';')
chan=out['channel'].unique().tolist()
len(chan)
# Out:
# 1676

# %%
db_video=db_video[~db_video['channel'].isin(chan)]
db_video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5596628 entries, 141 to 11845922
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0.1    int64
#  1   Unnamed: 0      int64
#  2   category        object
#  3   channel         object
#  4   date_crawled    object
#  5   description     object
#  6   id              object
#  7   duration        int64
#  8   tags            object
#  9   title           object
#  10  upload          object
#  11  week            object
#  12  before_updates  float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 597.8+ MB

# %%
max(db_video['week'])
# Out:
# '2017-43'

# %%
db_video['channel'].nunique()
# Out:
# 51859

# %% [markdown]
# ## Selecting before update videos

# %%
db_before=db_video[db_video['before_updates']==1]

# %%
db_before.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2742395 entries, 363 to 11845922
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0.1    int64
#  1   Unnamed: 0      int64
#  2   category        object
#  3   channel         object
#  4   date_crawled    object
#  5   description     object
#  6   id              object
#  7   duration        int64
#  8   tags            object
#  9   title           object
#  10  upload          object
#  11  week            object
#  12  before_updates  float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 292.9+ MB

# %%
db_before['channel'].nunique()
# Out:
# 51859

# %%
db_before['description'].isna().sum()
# Out:
# 78607

# %%
db_before['tags'].isna().sum()
# Out:
# 235058

# %%
db_before[['description','tags']].isna().all(axis=1).sum()
# Out:
# 45071

# %%
db_before['id'].count()
# Out:
# 2742395

# %% [markdown]
# ## Title, description and tags analysis

# %%
pattern_sex=[' ass ', ' sex ', ' dick ', ' vagina ', ' penis ', ' anal ', ' anus ', ' erotic ', 
             ' boobs ', ' butt ', ' cum ', ' nudity ', ' sexual ', ' porn ', ' xxx ', ' fuck ', ' condom ']
 
pattern_sex = re.compile('|'.join(pattern_sex))   
mask = ((db_before['title'].str.contains(pattern_sex))|(db_before['description'].str.contains(pattern_sex))|(db_before['tags'].str.contains(pattern_sex)))
db_before['sex']=mask
db_before['sex']=db_before['sex'].fillna('None')
# Out:
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\1782510390.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['sex']=mask
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\1782510390.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['sex']=db_before['sex'].fillna('None')

# %%
db_before['sex'].value_counts()
# Out:
# sex
# False    2843584
# True       15746
# Name: count, dtype: int64

# %%
db_before[db_before['sex']==True]
# Out:
#           Unnamed: 0.1  Unnamed: 0              category  \
# 746               1204        2691  Science & Technology
# 749               1207        2694  Science & Technology
# 780               1238        2725  Science & Technology
# 781               1239        2726  Science & Technology
# 804               1262        2749  Science & Technology
# ...                ...         ...                   ...
# 11842202      18693022     2359306         Howto & Style
# 11842210      18693030     2359314         Howto & Style
# 11842212      18693032     2359316         Howto & Style
# 11842220      18693040     2359324         Howto & Style
# 11842222      18693042     2359326         Howto & Style
#
#                            channel                date_crawled  \
# 746       UCzWQYUVCpZqtN93H8RR44Qw  2019-11-03 22:22:23.728131
# 749       UCzWQYUVCpZqtN93H8RR44Qw  2019-11-03 22:22:25.524810
# 780       UCzWQYUVCpZqtN93H8RR44Qw  2019-11-03 22:21:45.177946
# 781       UCzWQYUVCpZqtN93H8RR44Qw  2019-11-03 22:21:45.754262
# 804       UCzWQYUVCpZqtN93H8RR44Qw  2019-11-03 22:21:59.405248
# ...                            ...                         ...
# 11842202  UCs8moRYU6xw11rTqlIQ6KRw  2019-11-19 14:57:28.948340
# 11842210  UCs8moRYU6xw11rTqlIQ6KRw  2019-11-19 14:57:33.846920
# 11842212  UCs8moRYU6xw11rTqlIQ6KRw  2019-11-19 14:57:35.066883
# 11842220  UCs8moRYU6xw11rTqlIQ6KRw  2019-11-19 14:57:40.348296
# 11842222  UCs8moRYU6xw11rTqlIQ6KRw  2019-11-19 14:57:41.709816
#
#                                                 description           id  \
# 746       The U.S. legal abortion rate is at an all-time...  3jWjaHWQ-00
# 749       A female shark spontaneously gave birth after ...  1mS10pRK8rE
# 780       Do illnesses really affect men worse than wome...  5axqfvcnlMQ
# 781       Scientists discovered a millipede that has 414...  MhNDsJNcy3g
# 804       Why does the honeymoon phase at the beginning ...  JWc3Ql0vsvc
# ...                                                     ...          ...
# 11842202  HAPPY NEW YEAR!!! YAAASSS!! What a better way ...  Pgfe336MUn4
# 11842210  Get ready to HATE ME today!! LOL! We love lung...  i93tzqOl0LY
# 11842212  Good morning!! Kettle bell workout today!  I m...  ZyfQP82L6So
# 11842220  Good Weekend to you all!  Today I am doing ano...  qsj4Jecl_mA
# 11842222  Ok Guys!! Happy weekend!! Lets get those ARMS ...  n5MJoAgEFfw
#
#           duration                                               tags  \
# 746            276  current events,Science,abortion,sex education,...
# 749            275  current events,Science,asexual,parthenogenesis...
# 780            203  current events,Science,man flu,illness,men vs ...
# 781            202  current events,Science,penis,genitals,milliped...
# 804            192  current events,Science,love,relationships,pupp...
# ...            ...                                                ...
# 11842202      2050  WORKOUT,fitness over 40,makeup over 40,mature ...
# 11842210      1856  workout,fitness,mature beauty,fitness over 40,...
# 11842212      1557  YouTube Editor,Hiit,workout,womens workouts,fa...
# 11842220      1738  YouTube Editor,workout,hiit,fitness,fitover40,...
# 11842222      1818  fitness,fitness for women,fit over 40,mature s...
#
#                                                       title      upload  \
# 746           The Abortion Rate Is At An All-Time Low, Why?  2017-01-26
# 749       This Shark Reproduced Without A Mate! Could Hu...  2017-01-25
# 780                  Men vs. Women: Who Really Gets Sicker?  2017-01-03
# 781               This Animal Has Penises For Legs... WHY?!  2017-01-02
# 804       The Scientific Reason The ‘Honeymoon Phase’ Go...  2016-12-14
# ...                                                     ...         ...
# 11842202   NEW YEARS EVE WORKOUT 2017! ALL QUADS AND PECS!!  2016-12-31
# 11842210  Killer 30 minute quad and glute at home workou...  2016-11-12
# 11842212  FITNESS OVER 40---25 minute GIRLS RULE kettle ...  2016-10-29
# 11842220  25 minute low impact silent injury workout # 2...  2016-09-03
# 11842222  25 minute Little miss chatter box CARDIO ARMS ...  2016-08-20
#
#              week  before_updates   sex
# 746       2017-04             1.0  True
# 749       2017-04             1.0  True
# 780       2017-01             1.0  True
# 781       2017-01             1.0  True
# 804       2016-50             1.0  True
# ...           ...             ...   ...
# 11842202  2016-52             1.0  True
# 11842210  2016-45             1.0  True
# 11842212  2016-43             1.0  True
# 11842220  2016-35             1.0  True
# 11842222  2016-33             1.0  True
#
# [15746 rows x 14 columns]

# %%
pattern_violence=[' blood ', ' torture ', ' murder ', ' abuse ', ' rape ', ' kill ', ' dead ', ' mass shooting ', 
                  ' execution ', ' kidnapping ', ' slaughter ', ' suicide ', ' victim ', 
                  ' violence ', ' violent ', ' weapon ', ' warefare ', ' gun', ' bomb', ' terrorism ', " extremism "]

pattern_violence= re.compile('|'.join(pattern_violence))   
mask_violence = ((db_before['title'].str.contains(pattern_violence))|(db_before['description'].str.contains(pattern_violence))|(db_before['tags'].str.contains(pattern_violence)))
db_before['violence']=mask_violence
db_before['violence']=db_before['violence'].fillna('No tags')
# Out:
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\2189028372.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['violence']=mask_violence
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\2189028372.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['violence']=db_before['violence'].fillna('No tags')

# %%
db_before['violence'].value_counts()
# Out:
# violence
# False    2769412
# True       89918
# Name: count, dtype: int64

# %%
pattern_insults=[' bastard ', ' pussy ', ' dumbass ', ' goddamn ', ' bitch ', ' nigger ', ' shit ', ' idiot ', 
                 ' dammit ', ' cunt ']

pattern_insults= re.compile('|'.join(pattern_insults))   
mask_insults = ((db_before['title'].str.contains(pattern_insults))|(db_before['description'].str.contains(pattern_insults))|(db_before['tags'].str.contains(pattern_insults)))
db_before['insults']=mask_insults
db_before['insults']=db_before['insults'].fillna('No tags')
# Out:
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\939420917.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['insults']=mask_insults
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\939420917.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['insults']=db_before['insults'].fillna('No tags')

# %%
db_before['insults'].value_counts()
# Out:
# insults
# False    2852568
# True        6762
# Name: count, dtype: int64

# %%
pattern_drug=[" acid ", ' drug ', ' weed ', ' boong ', ' cannabis ', ' cbd ', ' cocain ', ' crack ',
              ' dealer ', ' joint ', ' junky ', ' lsd ', ' marijuana ', ' rehab ', 
               ' stoned ',  ' thc ', ' heroin']

pattern_drug= re.compile('|'.join(pattern_drug))   
mask_drug = ((db_before['title'].str.contains(pattern_drug))|(db_before['description'].str.contains(pattern_drug))|(db_before['tags'].str.contains(pattern_drug)))
db_before['drug']=mask_drug
db_before['drug']=db_before['drug'].fillna('No tags')
# Out:
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\4059495252.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['drug']=mask_drug
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\4059495252.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['drug']=db_before['drug'].fillna('No tags')

# %%
db_before['drug'].value_counts()
# Out:
# drug
# False    2847489
# True       11841
# Name: count, dtype: int64

# %%
pattern_sensitive=[" war ", " abortion ", " accident ", " Hitler ",  " fascism ",  " AIDS ", " Al Qaeda ", " alt right ", 
                   " genocide ", ' assassination ',
                   ' attack ', " concentration camp ",  " incel ",  " holocaust ",  " homophobia ", " illegal ", " incest ", " ISIS ", 
                   " Israel ", " Palestine ", " jewish ",  " Ku Klux Klan ", " LGBT ",   " nazi ", 
                   ' racism ', ' slavery ', ' supremacist ', ' supremacy ', ' transphobia ',  ' nuclear weapon ', ' climate change ', ' 9/11 ', ' Twin Towers ']

pattern_sensitive= re.compile('|'.join(pattern_sensitive))   
mask_sensitive = ((db_before['title'].str.contains(pattern_sensitive))|(db_before['description'].str.contains(pattern_sensitive))|(db_before['tags'].str.contains(pattern_sensitive)))
db_before['sensitive']=mask_sensitive
db_before['sensitive']=db_before['sensitive'].fillna('No tags')
# Out:
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\332034971.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['sensitive']=mask_sensitive
# C:\Users\mrass\AppData\Local\Temp\ipykernel_18680\332034971.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_before['sensitive']=db_before['sensitive'].fillna('No tags')

# %%
db_before['sensitive'].value_counts()
# Out:
# sensitive
# False    2815276
# True       44054
# Name: count, dtype: int64

# %% [markdown]
# ## Selecting channels based on keyword analysis

# %%
db_channels=db_before.groupby(['channel','sex'], as_index=False).size()
db_channels
# Out:
#                         channel    sex  size
# 0      UC--24Q3_ZQeFmgJE-Um5QZQ  False    31
# 1      UC--2EbuIuBOGgGqPiJxi3rg  False     5
# 2      UC--3ozenTzry39-xMqAPQlw  False     7
# 3      UC--6E6EpybocdaNlPhvK_9A  False     4
# 4      UC--70ql_IxJmhmqXqrkJrWQ  False    33
# ...                         ...    ...   ...
# 58660  UCzzqd0yx7h1PuC3KJVqeJgw  False    77
# 58661  UCzzt-UNlRHbEFY3rEpFpuXw  False    11
# 58662  UCzzzPMh9fZHxc7gxPRB2LHQ  False   158
# 58663  UCzzzPMh9fZHxc7gxPRB2LHQ   True     4
# 58664  UCzzzZ3-icktxbC3j7hkWqRw  False     1
#
# [58665 rows x 3 columns]

# %%
db_cha_sex=pd.crosstab(db_before['channel'],db_before['sex'], margins=True)
db_cha_sex
# Out:
# sex                         False   True      All
# channel
# UC--24Q3_ZQeFmgJE-Um5QZQ       31      0       31
# UC--2EbuIuBOGgGqPiJxi3rg        5      0        5
# UC--3ozenTzry39-xMqAPQlw        7      0        7
# UC--6E6EpybocdaNlPhvK_9A        4      0        4
# UC--70ql_IxJmhmqXqrkJrWQ       33      0       33
# ...                           ...    ...      ...
# UCzzqd0yx7h1PuC3KJVqeJgw       77      0       77
# UCzzt-UNlRHbEFY3rEpFpuXw       11      0       11
# UCzzzPMh9fZHxc7gxPRB2LHQ      158      4      162
# UCzzzZ3-icktxbC3j7hkWqRw        1      0        1
# All                       2843584  15746  2859330
#
# [53293 rows x 3 columns]

# %%
db_cha_sex['percentage_true']=round((db_cha_sex[True]/db_cha_sex['All'])*100)

conditions=[(db_cha_sex['percentage_true']<=25),
    (db_cha_sex['percentage_true']>25)]
values=['Control','Treatment']

db_cha_sex['type_channel_sex']=np.select(conditions, values)

db_cha_sex.groupby(['type_channel_sex'], as_index=False).size()
# Out:
#   type_channel_sex  size
# 0          Control   514
# 1        Treatment   218

# %%
db_cha_violence=pd.crosstab(db_before['channel'],db_before['violence'], margins=True)
db_cha_violence['percentage_true']=round((db_cha_violence[True]/db_cha_violence['All'])*100)

conditions=[(db_cha_violence['percentage_true']<=25),
    (db_cha_violence['percentage_true']>25)]
values=['Control','Treatment']

db_cha_violence['type_channel_violence']=np.select(conditions, values)

db_cha_violence.groupby(['type_channel_violence'], as_index=False).size()
# Out:
#   type_channel_violence   size
# 0               Control  52161
# 1             Treatment   1132

# %%
db_cha_insults=pd.crosstab(db_before['channel'],db_before['insults'], margins=True)
db_cha_insults['percentage_true']=round((db_cha_insults[True]/db_cha_insults['All'])*100)

conditions=[(db_cha_insults['percentage_true']<=25),
    (db_cha_insults['percentage_true']>25)]
values=['Control','Treatment']

db_cha_insults['type_channel_insults']=np.select(conditions, values)

db_cha_insults.groupby(['type_channel_insults'], as_index=False).size()
# Out:
#   type_channel_insults   size
# 0              Control  53189
# 1            Treatment    104

# %%
db_cha_drugs=pd.crosstab(db_before['channel'],db_before['drug'], margins=True)
db_cha_drugs['percentage_true']=round((db_cha_drugs[True]/db_cha_drugs['All'])*100)

conditions=[(db_cha_drugs['percentage_true']<=25),
    (db_cha_drugs['percentage_true']>25)]
values=['Control','Treatment']

db_cha_drugs['type_channel_drugs']=np.select(conditions, values)

db_cha_drugs.groupby(['type_channel_drugs'], as_index=False).size()
# Out:
#   type_channel_drugs   size
# 0            Control  53140
# 1          Treatment    153

# %%
db_cha_sens=pd.crosstab(db_before['channel'],db_before['sensitive'], margins=True)
db_cha_sens['percentage_true']=round((db_cha_sens[True]/db_cha_sens['All'])*100)

conditions=[(db_cha_sens['percentage_true']<=25),
    (db_cha_sens['percentage_true']>25)]
values=['Control','Treatment']

db_cha_sens['type_channel_sens']=np.select(conditions, values)

db_cha_sens.groupby(['type_channel_sens'], as_index=False).size()
# Out:
#   type_channel_sens   size
# 0           Control  52818
# 1         Treatment    475

# %%
db_cha_sex=db_cha_sex[db_cha_sex['type_channel_sex']=='Treatment']
db_cha_violence=db_cha_violence[db_cha_violence['type_channel_violence']=='Treatment']
db_cha_insults=db_cha_insults[db_cha_insults['type_channel_insults']=='Treatment']
db_cha_drugs=db_cha_drugs[db_cha_drugs['type_channel_drugs']=='Treatment']
db_cha_sens=db_cha_sens[db_cha_sens['type_channel_sens']=='Treatment']

# %%
db_cha=list(db_cha_sex.index)

db_violence=list(db_cha_violence.index)
db_insults=list(db_cha_insults.index)
db_drugs=list(db_cha_drugs.index)
db_sens=list(db_cha_sens.index)

# %%
for ele in db_violence:
    if ele in db_cha:
        1
    else:
        db_cha.append(ele)

for ele in db_insults:
    if ele in db_cha:
        1
    else:
        db_cha.append(ele)

for ele in db_drugs:
    if ele in db_cha:
        1
    else:
        db_cha.append(ele)


for ele in db_sens:
    if ele in db_cha:
        1
    else:
        db_cha.append(ele)

print(len(db_cha))
# Out:
# 1906

# %%
data={'id_channel':db_cha}
db=pd.DataFrame(data)

db['type']='treatment'
db.to_csv('id_channels_treatment_25.csv', sep=';')
